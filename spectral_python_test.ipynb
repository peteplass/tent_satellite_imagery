# %%
import geopandas as gpd
import folium
from scipy import ndimage as ndi
# %config InlineBackend.figure_format = 'retina'
import numpy as np

from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import train_test_split
import sys
from spectral import *
import spectral.io.aviris as aviris

# %%
img = open_image('./ModDimensionDataSet/flc1.lan')

# %%
img.__class__
# Out:
# spectral.io.bilfile.BilFile

# %%
img.shape
# Out:
# (949, 220, 12)

# %%
pixel = img[50, 100]

# %%
pixel.shape
# Out:
# (12,)

# %%
band6 = img[:, :, 5]

# %%
band6.shape
# Out:
# (949, 220, 1)

# %%
arr = img.load()
arr.__class__
# Out:
# spectral.spectral.ImageArray

# %%
print (arr.info())
# Out:
# 	# Rows:            949
# 	# Samples:         220
# 	# Bands:            12
# 	Data format:   float32

# %%
arr.shape
# Out:
# (949, 220, 12)

# %%
gt = img.read_band(10)

# %%
gt.shape
# Out:
# (949, 220)

# %%
view = imshow(img, classes = gt)

# %%
view = imshow(img, (11, 1, 11), classes=gt)

# %%
ImageView.open_zoom(view)
# Out:
# ImageView object:
#   Display bands       :  (11, 1, 11)
#   Interpolation       :  nearest
#   RGB data limits     :
#     R: [-128.0, 127.0]
#     G: [-128.0, 127.0]
#     B: [-128.0, 127.0]

# %%
ImageView
# Out:
# spectral.graphics.spypylab.ImageView

# %%
aviris.read_aviris_bands('./ModDimensionDataSet/flc1.lan')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-83-fe984e54f84e> in <module>
# ----> 1 aviris.read_aviris_bands('./ModDimensionDataSet/flc1.lan')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/spectral/io/aviris.py in read_aviris_bands(cal_filename)
#     131     bands.band_unit = 'nm'
#     132
# --> 133     fin = builtins.open(find_file_path(cal_filename))
#     134     rows = [line.split() for line in fin]
#     135     rows = [[float(x) for x in row] for row in rows if len(row) == 5]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/spectral/io/spyfile.py in find_file_path(filename)
#     142           'use its full path or place its directory in the ' \
#     143           'SPECTRAL_DATA environment variable.'  % filename
# --> 144         raise FileNotFoundError(msg)
#     145     return pathname
#     146
#
# FileNotFoundError: Unable to locate file "./ModDimensionDataSet/flc1.lan". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.

# %%
 view_cube(img, bands=[9, 9, 9])
# Out:
# /Users/peterplass/opt/anaconda3/lib/python3.7/site-packages/spectral/graphics/graphics.py:800: UserWarning:
# There is no current wx.App object - creating one now.
#   UserWarning)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: This program needs access to the screen. Please run with a
# Framework build of python, and only when you are logged in
# on the main display of your Mac.
# /Users/peterplass/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# Out:
#   File "<ipython-input-43-14e75ea99dd1>", line 1
#     print img
#             ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(img)?

# %%
pip install wxpython
# Out:
# Collecting wxpython
#   Downloading wxPython-4.0.7.post2-cp37-cp37m-macosx_10_9_x86_64.whl (16.9 MB)
#      |████████████████████████████████| 16.9 MB 2.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy; python_version >= "3.0" in /Users/peterplass/.local/lib/python3.7/site-packages (from wxpython) (1.18.1)
# Requirement already satisfied: pillow in /Users/peterplass/opt/anaconda3/lib/python3.7/site-packages (from wxpython) (7.0.0)
# Requirement already satisfied: six in /Users/peterplass/opt/anaconda3/lib/python3.7/site-packages (from wxpython) (1.14.0)
# Installing collected packages: wxpython
# Successfully installed wxpython-4.0.7.post2
# Note: you may need to restart the kernel to use updated packages.
