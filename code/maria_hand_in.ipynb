# %%
from spectral import *
import folium
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
img1 = open_image('./Leogane-images/Leogane-2008-final.lan')

# %%
img2 = open_image('./Leogane-images/Leogane-2008-zoomed.lan')

# %%
img1.__class__
# Out:
# spectral.io.bilfile.BilFile

# %%
img2.__class__
# Out:
# spectral.io.bilfile.BilFile

# %%
img1.shape
# Out:
# (3834, 3800, 4)

# %%
img2.shape
# Out:
# (547, 760, 4)

# %%
pixel1 = img1[50, 100]

# %%
pixel2 = img2[50, 100]

# %%
pixel1.shape
# Out:
# (4,)

# %%
pixel2.shape
# Out:
# (4,)

# %%
band4_img1 = img1[:, :, 3]

# %%
band4_img2 = img2[:, :, 3]

# %%
band4_img1.shape
# Out:
# (3834, 3800, 1)

# %%
band4_img2.shape
# Out:
# (547, 760, 1)

# %%
arr_1 = img1.load()
arr_1.__class__
# Out:
# spectral.spectral.ImageArray

# %%
arr_2 = img2.load()
arr_2.__class__
# Out:
# spectral.spectral.ImageArray

# %%
print (arr_1.info())
# Out:
# 	# Rows:           3834
# 	# Samples:        3800
# 	# Bands:             4
# 	Data format:   float32

# %%
print (arr_2.info())
# Out:
# 	# Rows:            547
# 	# Samples:         760
# 	# Bands:             4
# 	Data format:   float32

# %%
arr_1.shape
# Out:
# (3834, 3800, 4)

# %%
arr_2.shape
# Out:
# (547, 760, 4)

# %%
gt_1 = img1.read_band(3)

# %%
view_1 = imshow(img1, classes = gt_1)

# %%
view_1 = imshow(img1, (0, 1, 2), classes=gt_1)

# %%
ImageView.open_zoom(view_1)
# Out:
# /Users/mariaflores/anaconda3/lib/python3.7/site-packages/spectral/graphics/spypylab.py:922: UserWarning: ImageView.show_classes should only be called once.
#   warnings.warn(UserWarning(msg))

# %%
gt_2 = img2.read_band(3)

# %%
view_2 = imshow(img2, classes = gt_2)

# %%
view_2 = imshow(img2, (0, 1, 2), classes = gt_2)

# %%
ImageView.open_zoom(view_2)

# %%
from platform import python_version

print(python_version())

# %%
import labelImg
